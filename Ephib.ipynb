# %% [markdown]
# # Отслеживание окончания трудовых договоров сотрудников ИФИБ
# В ИФИБ НИЯУ МИФИ работают сотрудники с определенным сроком, прописанным в трудовом договоре, который необходимо регулярно мониторить, т.к. процесс переоформления / продления / увольнения сотрудников занимает много времени.
#
# Чтобы избежать накладок и ускорить процесс работы, был разработан алгоритм еженедельного отслеживания окончания трудовых договоров:
# - загрузка файла с актуальным на текущую дату списком сотрудников ИФИБ в Jupiter Notebook
# - обработка данных для дальнейшей работы (переименовывание колонок, изменение типа данных, удаление записей о бессрочных трудовых договорах)
# - добавление колонки, в которой указано количество оставшихся дней до окончания трудового договора (считая от текущей даты)
# - сортировка данных по возрастанию количества оставшихся дней
# - выделение цветом записей, требующих внимания
# - сохранение этих записей отдельным файлом с указанием текущей даты
# - отправление файла по API для дальнейшей работы с отделом кадров

# %%
# Грузим либы
import pandas as pd
import numpy as np
import datetime 
import requests
from urllib.parse import urlencode

import warnings
warnings.filterwarnings('ignore')

# %%
# Читаем выгрузку
ephib = pd.read_csv('C:/Users/Acer/Python/ифиб-22.01.24.csv')

# %%
ephib.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212 entries, 0 to 211
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   № п/п                      212 non-null    int64
#  1   ФИО                        212 non-null    object
#  2   Шифр                       212 non-null    int64
#  3   E-mail                     183 non-null    object
#  4   Должность                  212 non-null    object
#  5   Категория                  212 non-null    object
#  6   Ставка                     212 non-null    float64
#  7   Аудиторная нагрузка        212 non-null    int64
#  8   Руководтсво аспирантами    212 non-null    int64
#  9   Руководство студентами     212 non-null    int64
#  10  Тип                        212 non-null    object
#  11  Подразделение              212 non-null    object
#  12  Дата начала контракта      212 non-null    object
#  13  Дата завершения контракта  212 non-null    object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 23.3+ KB

# %%
# Для удобства переименовываем названия колонок
ephib = ephib.rename(columns={'№ п/п':'№', 'Аудиторная нагрузка':'Аудиторная_нагрузка', 
                            'Руководтсво аспирантами':'Руководство_аспирантами', 'Руководство студентами':'Руководство_студентами',
                            'Дата начала контракта':'Дата_начала_контракта', 'Дата завершения контракта':'Дата_завершения_контракта'})

# %%
# Зашифруем личные данные (ФИО и e-mail) (только для анонимности данных в открытом доступе)
ephib['ФИО']    = ephib['ФИО'].apply(lambda x: ''.join(word[0] for word in x.split()))
ephib['E-mail'] = ephib['E-mail'].astype(str).apply(lambda x: x[:3])

# %%
# Ищем бессрочные договоры
ephib.query('Дата_завершения_контракта == "-"')
# Out:
#        №  ФИО    Шифр E-mail                Должность Категория  Ставка  \
# 28    25  ГАА  390667    AAG         Начальник отдела       АУП     1.0
# 39    34  ГЕВ  263054    EVG    Заместитель директора       АУП     1.0
# 102   87  ЛНИ  660052    NIL  Заведующий лабораторией       УВП     1.0
# 128  112  НВВ  521121    VVN         Начальник отдела       АУП     1.0
# 169  145  САИ  147662    AIS          Ведущий инженер       УВП     1.0
# 204  176  ШЮВ   25347    YVS                   Тьютор       УВП     1.0
#
#      Аудиторная_нагрузка  Руководство_аспирантами  Руководство_студентами  \
# 28                    62                        0                       0
# 39                   162                        0                       0
# 102                   16                        0                       0
# 128                    0                        0                       0
# 169                   92                        0                       0
# 204                  219                        0                       0
#
#       Тип                                      Подразделение  \
# 28   штат  Отдел инновационных технологий в медицине инже...
# 39   штат  Инженерно-физический институт биомедицины НИЯУ...
# 102  штат                 Кафедра промышленной фармации (94)
# 128  штат  Организационно-технический отдел инженерно-физ...
# 169  штат                    Кафедра медицинской физики (35)
# 204  штат                    Кафедра медицинской физики (35)
#
#     Дата_начала_контракта Дата_завершения_контракта
# 28             01.01.2024                         -
# 39             01.01.2024                         -
# 102            01.01.2024                         -
# 128            01.01.2024                         -
# 169            01.12.2008                         -
# 204            01.01.2024                         -

# %%
# Убираем их из df
ephib = ephib.drop(np.where(ephib['Дата_завершения_контракта'] == "-")[0])

# %%
# Меняем тип данных для дат
ephib[['Дата_начала_контракта', 'Дата_завершения_контракта']] = ephib[['Дата_начала_контракта', 'Дата_завершения_контракта']].apply(pd.to_datetime, format='%d.%m.%Y')

# %%
# Создаем столбец с количеcтвом дней, которое осталось до окончания ТД
ephib['Осталось_дней'] = (ephib['Дата_завершения_контракта'] - pd.Timestamp.now().normalize()).dt.days.astype(int)

# %%
# Сортируем по возрастанию числа оставшихся дней
ephib = ephib.sort_values('Осталось_дней', ascending = True)
ephib.head()
# Out:
#        №  ФИО    Шифр E-mail              Должность Категория  Ставка  \
# 89    76  КЕВ  649957    nan               Лаборант       УВП    0.25
# 51    43  ДОН  672461    OND                 Доцент       Поч    1.00
# 176  151  САИ  670811    AIS  Заведующий отделением       Поч    1.00
# 70    60  ИДС  667925    DSI                 Доцент       ППС    0.10
# 152  132  СТА  589450    TAS                 Доцент       ППС    0.25
#
#      Аудиторная_нагрузка  Руководство_аспирантами  Руководство_студентами  \
# 89                     0                        0                       0
# 51                    54                        0                       0
# 176                   34                        0                       0
# 70                    48                        0                       0
# 152                   93                      100                       0
#
#               Тип                                      Подразделение  \
# 89           штат                    Кафедра медицинской физики (35)
# 51        договор  Инженерно-физический институт биомедицины НИЯУ...
# 176       договор  Инженерно-физический институт биомедицины НИЯУ...
# 70   внешн. совм.                      Кафедра ядерной медицины (85)
# 152  внешн. совм.  Отделение биотехнологий офиса образовательных ...
#
#     Дата_начала_контракта Дата_завершения_контракта  Осталось_дней
# 89             2023-03-13                2024-01-31              6
# 51             2023-11-14                2024-01-31              6
# 176            2023-11-01                2024-01-31              6
# 70             2023-09-22                2024-01-31              6
# 152            2024-01-01                2024-01-31              6

# %%
# Цветом выделяем ТД, подходящие к окончанию срока
def highlight_col(x):
    ephib = x.copy()
    mask_1 = ephib['Осталось_дней'] <= 21 
    mask_2 = ephib['Осталось_дней'] > 21 
    mask_3 = ephib['Осталось_дней'] > 31
    ephib.loc[mask_1, :] = 'background-color: #FFB6C1'
    ephib.loc[mask_2, :] = 'background-color: #FFF68F'
    ephib.loc[mask_3, :] = 'background-color: ""'
    return ephib   

ephib.style.apply(highlight_col, axis=None)
# Out:
# <style type="text/css">
# #T_1e4b7_row0_col0, #T_1e4b7_row0_col1, #T_1e4b7_row0_col2, #T_1e4b7_row0_col3, #T_1e4b7_row0_col4, #T_1e4b7_row0_col5, #T_1e4b7_row0_col6, #T_1e4b7_row0_col7, #T_1e4b7_row0_col8, #T_1e4b7_row0_col9, #T_1e4b7_row0_col10, #T_1e4b7_row0_col11, #T_1e4b7_row0_col12, #T_1e4b7_row0_col13, #T_1e4b7_row0_col14, #T_1e4b7_row1_col0, #T_1e4b7_row1_col1, #T_1e4b7_row1_col2, #T_1e4b7_row1_col3, #T_1e4b7_row1_col4, #T_1e4b7_row1_col5, #T_1e4b7_row1_col6, #T_1e4b7_row1_col7, #T_1e4b7_row1_col8, #T_1e4b7_row1_col9, #T_1e4b7_row1_col10, #T_1e4b7_row1_col11, #T_1e4b7_row1_col12, #T_1e4b7_row1_col13, #T_1e4b7_row1_col14, #T_1e4b7_row2_col0, #T_1e4b7_row2_col1, #T_1e4b7_row2_col2, #T_1e4b7_row2_col3, #T_1e4b7_row2_col4, #T_1e4b7_row2_col5, #T_1e4b7_row2_col6, #T_1e4b7_row2_col7, #T_1e4b7_row2_col8, #T_1e4b7_row2_col9, #T_1e4b7_row2_col10, #T_1e4b7_row2_col11, #T_1e4b7_row2_col12, #T_1e4b7_row2_col13, #T_1e4b7_row2_col14, #T_1e4b7_row3_col0, #T_1e4b7_row3_col1, #T_1e4b7_row3_col2, #T_1e4b7_row3_col3, #T_1e4b7_row3_col4, #T_1e4b7_row3_col5, #T_1e4b7_row3_col6, #T_1e4b7_row3_col7, #T_1e4b7_row3_col8, #T_1e4b7_row3_col9, #T_1e4b7_row3_col10, #T_1e4b7_row3_col11, #T_1e4b7_row3_col12, #T_1e4b7_row3_col13, #T_1e4b7_row3_col14, #T_1e4b7_row4_col0, #T_1e4b7_row4_col1, #T_1e4b7_row4_col2, #T_1e4b7_row4_col3, #T_1e4b7_row4_col4, #T_1e4b7_row4_col5, #T_1e4b7_row4_col6, #T_1e4b7_row4_col7, #T_1e4b7_row4_col8, #T_1e4b7_row4_col9, #T_1e4b7_row4_col10, #T_1e4b7_row4_col11, #T_1e4b7_row4_col12, #T_1e4b7_row4_col13, #T_1e4b7_row4_col14, #T_1e4b7_row5_col0, #T_1e4b7_row5_col1, #T_1e4b7_row5_col2, #T_1e4b7_row5_col3, #T_1e4b7_row5_col4, #T_1e4b7_row5_col5, #T_1e4b7_row5
_1e4b7_row17_col13, #T_1e4b7_row17_col14, #T_1e4b7_row18_col0, #T_1e4b7_row18_col1, #T_1e4b7_row18_col2, #T_1e4b7_row18_col3, #T_1e4b7_row18_col4, #T_1e4b7_row18_col5, #T_1e4b7_row18_col6, #T_1e4b7_row18_col7, #T_1e4b7_row18_col8, #T_1e4b7_row18_col9, #T_1e4b7_row18_col10, #T_1e4b7_row18_col11, #T_1e4b7_row18_col12, #T_1e4b7_row18_col13, #T_1e4b7_row18_col14, #T_1e4b7_row19_col0, #T_1e4b7_row19_col1, #T_1e4b7_row19_col2, #T_1e4b7_row19_col3, #T_1e4b7_row19_col4, #T_1e4b7_row19_col5, #T_1e4b7_row19_col6, #T_1e4b7_row19_col7, #T_1e4b7_row19_col8, #T_1e4b7_row19_col9, #T_1e4b7_row19_col10, #T_1e4b7_row19_col11, #T_1e4b7_row19_col12, #T_1e4b7_row19_col13, #T_1e4b7_row19_col14, #T_1e4b7_row20_col0, #T_1e4b7_row20_col1, #T_1e4b7_row20_col2, #T_1e4b7_row20_col3, #T_1e4b7_row20_col4, #T_1e4b7_row20_col5, #T_1e4b7_row20_col6, #T_1e4b7_row20_col7, #T_1e4b7_row20_col8, #T_1e4b7_row20_col9, #T_1e4b7_row20_col10, #T_1e4b7_row20_col11, #T_1e4b7_row20_col12, #T_1e4b7_row20_col13, #T_1e4b7_row20_col14, #T_1e4b7_row21_col0, #T_1e4b7_row21_col1, #T_1e4b7_row21_col2, #T_1e4b7_row21_col3, #T_1e4b7_row21_col4, #T_1e4b7_row21_col5, #T_1e4b7_row21_col6, #T_1e4b7_row21_col7, #T_1e4b ...

# %%
# Выносим итоговый вердикт и при необходимости сохраняем файл с записями, требующими внимания
if ephib.query('Осталось_дней < 32').shape[0] > 0:
    print('Alarm! Нужно заняться продлением ТД либо увольнением! Следующая проверка ' + str(datetime.date.today() + datetime.timedelta(days=7)))
    alarm_ephib = ephib.query('Осталось_дней < 32')
    alarm_ephib.to_csv('alarm_ephib_{}.csv'.format(datetime.date.today()))
else:
    print('Все в порядке, следующая проверка ' + str(datetime.date.today() + datetime.timedelta(days=7)))
# Out:
# Alarm! Нужно заняться продлением ТД либо увольнением! Следующая проверка 2024-02-01

# %%
token = '*****'
chat_id = 724965106  

message = 'Alarm! Нужно заняться продлением ТД либо увольнением! Следующая проверка ' + str(datetime.date.today() + datetime.timedelta(days=7)) 
params = {'chat_id': chat_id, 'text': message}

base_url = f'https://api.telegram.org/bot{token}/'
url_1 = base_url + 'sendMessage?' + urlencode(params)
resp = requests.get(url_1)

filepath = 'C:/Users/Acer/Python/alarm_ephib_{}.csv'.format(datetime.date.today())
url_2 = base_url + 'sendDocument?' + urlencode(params)
files = {'document': open(filepath, 'rb')}
resp = requests.get(url_2, files=files)
